# %%
from pydantic import BaseModel
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules


# 併売データ（例として使用する）
df = pd.read_csv('./hayatomo_6000_oh.csv', index_col=0)

#print(df.tail(50))

#””対策
import ast
df['ppv_history'] = df['ppv_history'].apply(lambda x: ast.literal_eval(x))

transactions = df['ppv_history'].values.tolist()#[:100]
#print(transactions)

# データをワンホットエンコーディング
def encode_transactions(transactions):
    all_items = sorted(set(item for sublist in transactions for item in sublist))
    encoded_df = pd.DataFrame([[int(item in transaction) for item in all_items] for transaction in transactions], columns=all_items)
    return encoded_df

# アポリオリアルゴリズムを実行
def apriori_algorithm(transactions):
    df_encoded = encode_transactions(transactions)
    frequent_itemsets = apriori(df_encoded, min_support=0.02, use_colnames=True)
    rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.1, num_itemsets=len(frequent_itemsets))
    rules_set = rules.sort_values(by='support', ascending=False)
    return rules_set

# ルールから特定の商品に関連する信頼度TOP10を抽出
def get_top_10_confidence_items(item_id, rules):
    
    # antecedentsが1つのアイテムだけで構成されているルールをフィルタリング
    filtered_rules = rules[rules['antecedents'].apply(lambda x: len(x) == 1 and item_id in list(x))]

    #　信頼度をもとにしてtop10を表示
    top_10 = filtered_rules.sort_values(by='confidence', ascending=False)#.head(200)
    
    associated_items = [list(rule['consequents'])[0] for _, rule in top_10.iterrows() if len(rule['consequents']) == 1]   #return [item for sublist in associated_items for item in sublist]

    return associated_items


#df_encoded = encode_transactions(transactions)
#print(df_encoded)
#rules = apriori_algorithm(transactions)
#print(rules)

item_list = ['002', '003', '009', '403', '035', '036', '008', '001', '010', '020', '024', '026', '025', '052', '402', '5', '027', '028', '021', '022', '061', '055', '046', '004', '015', '016', '031', '032', '059', '049', '058', '610', '060', '041', '029', '006', '007', '012', '018', '019', '023', '051', '045']

# 推奨商品を抽出

recommendations = []
for il in item_list:
    rules = apriori_algorithm(transactions)
    #print(rules)
    
    top_items = get_top_10_confidence_items(il, rules)
    recommendations.append([il , top_items])
    
    print(il , top_items , len(top_items))

#df = pd.DataFrame(recommendations, columns=['Key', 'Value'])
#df.to_csv('basket.csv')
# Out:
# /opt/conda/lib/python3.10/site-packages/mlxtend/frequent_patterns/fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# 002 ['009', '005', '008', '016', '003', '017', '055', '018', '021', '024', '025', '020', '027', '403', '046', '026', '069', '031', '022', '029'] 20
# /opt/conda/lib/python3.10/site-packages/mlxtend/frequent_patterns/fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# 003 ['005', '002', '009', '008', '001', '004', '010', '055', '014', '018'] 10
# /opt/conda/lib/python3.10/site-packages/mlxtend/frequent_patterns/fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# 009 ['002', '005', '008', '017', '016', '018', '055', '025', '020', '024', '027', '021', '003', '046', '031', '022', '026', '029', '069', '015', '030', '033', '072', '023', '019'] 25
# /opt/conda/lib/python3.10/site-packages/mlxtend/frequent_patterns/fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# 403 ['005', '002', '009', '008', '014', '001', '010', '055'] 8
# /opt/conda/lib/python3.10/site-packages/mlxtend/frequent_patterns/fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# 035 ['005', '003'] 2
# /opt/conda/lib/python3.10/site-packages/mlxtend/frequent_patterns/fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# 036 ['002', '009', '005'] 3
# /opt/conda/lib/python3.10/site-packages/mlxtend/frequent_patterns/fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# 008 ['002', '009', '005', '016', '024', '026', '025', '055', '003', '019', '018', '031', '017', '021', '046', '027', '020', '069', '029', '015', '072', '022', '403', '060', '030', '001', '033', '058', '100', '610', '079', '011', '057', '053', '023', '006', '068', '091', '084', '066', '065'] 41
# /opt/conda/lib/python3.10/site-packages/mlxtend/frequent_patterns/fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# 001 ['005', '003', '004', '002', '009', '008', '403', '012', '010'] 9
# /opt/conda/lib/python3.10/site-packages/mlxtend/frequent_patterns/fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# 010 ['005', '003', '001', '403', '014'] 5
# /opt/conda/lib/python3.10/site-packages/mlxtend/frequent_patterns/fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# 020 ['002', '009', '018', '005', '017', '016', '027', '008', '021', '025', '024', '046', '069', '055', '030', '022', '072', '029', '026', '060', '032', '033', '065', '019', '028', '051', '031', '015', '056'] 29
# /opt/conda/lib/python3.10/site-packages/mlxtend/frequent_patterns/fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# 024 ['002', '009', '005', '008', '017', '025', '016', '046', '022', '021', '026', '027', '031', '069', '018', '029', '072', '030', '020', '023', '019', '033', '055', '028', '051', '032', '073', '065', '060', '003', '056', '057', '058', '084', '052'] 35
# /opt/conda/lib/python3.10/site-packages/mlxtend/frequent_patterns/fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# 026 ['002', '008', '009', '005', '024', '025', '031', '027', '017', '022', '046', '072', '029', '016', '018', '021', '069', '033', '020', '019', '060', '030', '032', '084', '073'] 25
# /opt/conda/lib/python3.10/site-packages/mlxtend/frequent_patterns/fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# 025 ['002', '009', '024', '027', '008', '017', '046', '005', '016', '026', '021', '029', '018', '020', '031', '069', '022', '030', '072', '033', '060', '065', '068', '055', '019', '057', '023', '032', '051', '028', '073', '053', '056', '079'] 34
# /opt/conda/lib/python3.10/site-packages/mlxtend/frequent_patterns/fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# 052 ['002', '005', '009', '032', '017', '018', '024', '051', '069'] 9
# /opt/conda/lib/python3.10/site-packages/mlxtend/frequent_patterns/fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# 402 ['009', '002', '005'] 3
# /opt/conda/lib/python3.10/site-packages/mlxtend/frequent_patterns/fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# 5 [] 0
# /opt/conda/lib/python3.10/site-packages/mlxtend/frequent_patterns/fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# 027 ['002', '009', '025', '005', '016', '017', '024', '021', '020', '026', '008', '029', '033', '018', '031', '069', '072', '046', '022', '030', '032', '028', '055', '065', '051', '060', '073', '019', '056', '058', '068', '023', '084'] 33
# /opt/conda/lib/python3.10/site-packages/mlxtend/frequent_patterns/fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# 028 ['002', '009', '069', '027', '005', '017', '032', '024', '016', '033', '022', '030', '025', '072', '065', '020', '060', '018', '031', '029', '051', '046', '055', '021'] 24
# /opt/conda/lib/python3.10/site-packages/mlxtend/frequent_patterns/fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# 021 ['002', '009', '016', '005', '017', '018', '024', '008', '027', '025', '020', '046', '055', '072', '022', '026', '031', '069', '019', '030', '029', '023', '033', '073', '003', '060', '028', '068', '057'] 29
# /opt/conda/lib/python3.10/site-packages/mlxtend/frequent_patterns/fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# 022 ['002', '009', '024', '017', '005', '016', '026', '072', '025', '027', '046', '018', '008', '029', '069', '033', '021', '031', '020', '030', '065', '028', '032', '073', '056', '023', '060', '019', '051', '084'] 30
# /opt/conda/lib/python3.10/site-packages/mlxtend/frequent_patterns/fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# 061 [] 0
# /opt/conda/lib/python3.10/site-packages/mlxtend/frequent_patterns/fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# 055 ['002', '009', '005', '008', '016', '069', '003', '017', '018', '021', '020', '027', '046', '024', '025', '033', '072', '032', '015', '031', '030', '403', '028', '029'] 24
# /opt/conda/lib/python3.10/site-packages/mlxtend/frequent_patterns/fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# 046 ['002', '009', '024', '005', '025', '017', '008', '031', '069', '016', '027', '026', '030', '021', '020', '022', '018', '029', '032', '055', '072', '057', '033', '060', '023', '051', '065', '073', '068', '058', '011', '028'] 32
# /opt/conda/lib/python3.10/site-packages/mlxtend/frequent_patterns/fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# 004 ['005', '001', '003', '002'] 4
# /opt/conda/lib/python3.10/site-packages/mlxtend/frequent_patterns/fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# 015 ['002', '009', '005', '008', '016', '020', '055', '017', '072'] 9
# /opt/conda/lib/python3.10/site-packages/mlxtend/frequent_patterns/fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# 016 ['002', '009', '005', '017', '018', '008', '021', '024', '020', '027', '025', '022', '029', '069', '072', '055', '065', '046', '031', '030', '019', '023', '026', '068', '015', '033', '056', '028', '073', '060', '057', '003', '051', '032', '090', '085', '011'] 37
# /opt/conda/lib/python3.10/site-packages/mlxtend/frequent_patterns/fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# 031 ['002', '009', '005', '008', '029', '024', '026', '017', '027', '025', '046', '016', '018', '033', '030', '021', '022', '069', '032', '072', '023', '065', '051', '020', '056', '055', '060', '073', '028', '019'] 30
# /opt/conda/lib/python3.10/site-packages/mlxtend/frequent_patterns/fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# 032 ['002', '009', '017', '069', '046', '051', '005', '027', '072', '028', '033', '030', '031', '022', '024', '029', '025', '057', '055', '018', '020', '065', '052', '016', '026', '058', '060', '073', '023'] 29
# /opt/conda/lib/python3.10/site-packages/mlxtend/frequent_patterns/fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# 059 [] 0
# /opt/conda/lib/python3.10/site-packages/mlxtend/frequent_patterns/fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# 049 [] 0
# /opt/conda/lib/python3.10/site-packages/mlxtend/frequent_patterns/fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# 058 ['002', '009', '008', '060', '072', '027', '017', '024', '046', '005', '032', '069'] 12
# /opt/conda/lib/python3.10/site-packages/mlxtend/frequent_patterns/fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# 610 ['002', '009', '005', '008'] 4
# /opt/conda/lib/python3.10/site-packages/mlxtend/frequent_patterns/fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# 060 ['002', '009', '005', '008', '072', '025', '046', '018', '017', '027', '069', '026', '065', '058', '016', '020', '024', '022', '021', '051', '031', '028', '029', '056', '066', '073', '032'] 27
# /opt/conda/lib/python3.10/site-packages/mlxtend/frequent_patterns/fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# 041 [] 0
# /opt/conda/lib/python3.10/site-packages/mlxtend/frequent_patterns/fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# 029 ['002', '009', '031', '016', '005', '025', '027', '024', '017', '008', '030', '026', '046', '069', '022', '033', '018', '021', '072', '032', '020', '065', '060', '028', '019', '056', '051', '055', '066'] 29
# /opt/conda/lib/python3.10/site-packages/mlxtend/frequent_patterns/fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# 006 ['002', '009', '005', '008'] 4
# /opt/conda/lib/python3.10/site-packages/mlxtend/frequent_patterns/fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# 007 ['005', '002'] 2
# /opt/conda/lib/python3.10/site-packages/mlxtend/frequent_patterns/fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# 012 ['001'] 1
# /opt/conda/lib/python3.10/site-packages/mlxtend/frequent_patterns/fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# 018 ['002', '009', '016', '005', '017', '020', '021', '008', '024', '027', '025', '031', '022', '046', '072', '055', '030', '029', '026', '069', '060', '065', '003', '033', '032', '023', '051', '056', '073', '068', '052', '028', '019', '057', '045'] 35
# /opt/conda/lib/python3.10/site-packages/mlxtend/frequent_patterns/fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# 019 ['002', '008', '009', '017', '024', '005', '016', '021', '025', '026', '020', '027', '022', '018', '069', '031', '029'] 17
# /opt/conda/lib/python3.10/site-packages/mlxtend/frequent_patterns/fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# 023 ['002', '009', '024', '017', '016', '046', '069', '021', '025', '031', '022', '005', '018', '027', '008', '030', '032'] 17
# /opt/conda/lib/python3.10/site-packages/mlxtend/frequent_patterns/fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# 051 ['009', '002', '032', '017', '005', '027', '024', '046', '065', '025', '072', '069', '018', '030', '020', '022', '031', '016', '060', '028', '056', '057', '052', '029'] 24
# /opt/conda/lib/python3.10/site-packages/mlxtend/frequent_patterns/fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# 045 ['002', '009', '018', '057'] 4

# %%
import json

# リスト内包表記を使用して辞書のリストに変換
data_dict_list = [{'Key': key, 'Value': values} for key, values in recommendations]

# JSONファイルに保存
json_filename = 'output_basket.json'

with open(json_filename, 'w', encoding='utf-8') as f:
    json.dump(data_dict_list, f, ensure_ascii=False, indent=4)

print(f"データを '{json_filename}' に保存しました。")
# Out:
# データを 'output_basket.json' に保存しました。

# %%
transactions
# Out:
# [['403', '005', '005', '403', '5', '005'],
#  ['005', '002', '008', '017', '016', '103', '612', '124'],
#  ['403', '403', '403'],
#  ['014', '403', '002'],
#  ['002', '011', '009', '002'],
#  ['045', '624', '036', '002', '001', '021', '001', '653'],
#  ['013', '018', '016', '403', '008', '016', '021', '613', '002'],
#  ['403', '005', '014', '010'],
#  ['005', '010', '403', '001'],
#  ['005', '003', '072', '017', '058', '002', '072', '022', '090', '565', '086'],
#  ['005', '003', '035'],
#  ['003', '010', '001', '035', '512', '005'],
#  ['002', '009', '562'],
#  ['005', '003', '002', '020', '009', '031', '015', '017', '070', '622', '005'],
#  ['002', '009', '005'],
#  ['002', '009', '077', '055', '020'],
#  ['105', '504', '120'],
#  ['055', '402', '009'],
#  ['009', '002', '003', '005', '018', '017', '016', '001', '055'],
#  ['125', '033', '028', '026', '024', '022', '027', '131', '019'],
#  ['111',
#   '016',
#   '104',
#   '109',
#   '017',
#   '029',
#   '117',
#   '118',
#   '110',
#   '119',
#   '123',
#   '122',
#   '056'],
#  ['002', '652', '005'],
#  ['002', '612', '403', '005', '612', '403', '5'],
#  ['006',
#   '002',
#   '009',
#   '002',
#   '008',
#   '010',
#   '003',
#   '001',
#   '002',
#   '021',
#   '019',
#   '653',
#   '585',
#   '588',
#   '106',
#   '033',
#   '016',
#   '008',
#   '029',
#   '027',
#   '025',
#   '107',
#   '108',
#   '109',
#   '588',
#   '068',
#   '007',
#   '009'],
#  ['005', '004', '003', '004', '004', '070', '005', '004', '004', '005'],
#  ['002', '009', '098'],
#  ['005', '114', '129'],
#  ['016', '622', '024'],
#  ['610', '008', '002', '005'],
#  ['024', '24', '002', '084', '023', '861', '016', '111', '108', '122'],
#  ['005', '017', '016', '018', '002'],
#  ['009', '610', '002'],
#  ['005', '002', '621'],
#  ['005', '004', '003', '005'],
#  ['611', '002', '009', '002', '009', '055', '024', '025'],
#  ['055',
#   '008',
#   '002',
#   '024',
#   '021',
#   '015',
#   '025',
#   '105',
#   '022',
#   '106',
#   '864',
#   '079',
#   '107',
#   '017',
#   '111',
#   '113',
#   '016',
#   '114',
#   '115',
#   '117',
#   '857',
#   '072',
#   '085',
#   '121',
#   '125'],
#  ['002', '009', '036'],
#  ['005', '056', '016'],
#  ['002', '023', '039', '057', '080', '021', '009', '082'],
#  ['005', '052', '068', '864', '085'],
#  ['009', '002', '624', '005', '020', '030'],
#  ['002', '018', '016', '003', '009'],
#  ['005',
#   '036',
#   '028',
#   '019',
#   '021',
#   '002',
#   '008',
#   '061',
#   '546',
#   '007',
#   '001',
#   '014',
#   '060',
#   '057',
#   '065',
#   '024',
#   '025',
#   '069',
#   '068',
#   '071',
#   '062',
#   '072',
#   '007',
#   '045',
#   '546',
#   '005',
#   '055',
#   '575'],
#  ['002', '017', '009', '033', '624', '074', '075'],
#  ['005', '403', '010'],
#  ['002',
#   '068',
#   '827',
#   '025',
#   '831',
#   '005',
#   '610',
#   '016',
#   '027',
#   '072',
#   '021',
#   '073',
#   '009',
#   '023',
#   '065',
#   '024'],
#  ['005', '003', '014'],
#  ['003', '005', '002', '009', '002', '009', '002'],
#  ['003', '010', '014', '112', '114'],
#  ['008', '019', '079', '864', '008', '072', '068', '065'],
#  ['009', '109', '109', '118', '118', '002', '118', '118'],
#  ['009', '008', '002'],
#  ['006', '002', '031', '036'],
#  ['402', '009', '003', '005'],
#  ['005', '003', '113'],
#  ['002',
#   '009',
#   '002',
#   '614',
#   '002',
#   '009',
#   '002',
#   '015',
#   '018',
#   '019',
#   '016',
#   '009',
#   '021',
#   '008',
#   '017',
#   '055',
#   '024',
#   '022',
#   '020',
#   '025',
#   '005',
#   '069',
#   '072',
#   '028',
#   '091',
#   '092',
#   '033',
#   '030',
#   '082',
#   '027',
#   '864'],
#  ['403', '005', '007'],
#  ['006', '003', '002', '864', '832', '029'],
#  ['610', '002', '021', '005', '082', '107', '101', '120', '126', '133'],
#  ['008',
#   '517',
#   '041',
#   '026',
#   '818',
#   '819',
#   '047',
#   '059',
#   '061',
#   '063',
#   '064',
#   '067',
#   '831',
#   '827',
#   '057',
#   '862',
#   '074',
#   '008',
#   '104',
#   '111'],
#  ['403', '005', '010', '014'],
#  ['002', '009', '002'],
#  ['005', '005', '112', '005', '005', '005'],
#  ['052', '040', '862', '005', '086'],
#  ['002', '034', '003', '402', '005', '625', '077', '085'],
#  ['002', '055'],
#  ['007', '009', '556'],
#  ['002', '872', '099', '864', '107', '113', '111', '115', '121', '124'],
#  ['004', '001', '834'],
#  ['015',
#   '014',
#   '402',
#   '402',
#   '027',
#   '029',
#   '030',
#   '031',
#   '028',
#   '033',
#   '032',
#   '054',
#   '055',
#   '31',
#   '28',
#   '056',
#   '067',
#   '069',
#   '070',
#   '002',
#   '003',
#   '077'],
#  ['002', '003', '016'],
#  ['005', '852', '873', '002', '020', '103', '827'],
#  ['046', '005', '002', '015', '616', '072', '002', '002', '015', '103'],
#  ['006', '009', '002', '402', '532', '860', '006'],
#  ['002', '009', '005', '005'],
#  ['017',
#   '122',
#   '884',
#   '020',
#   '002',
#   '021',
#   '027',
#   '121',
#   '046',
#   '026',
#   '005',
#   '072',
#   '124',
#   '126',
#   '874'],
#  ['002', '008', '016'],
#  ['023',
#   '017',
#   '802',
#   '018',
#   '031',
#   '028',
#   '027',
#   '032',
#   '805',
#   '036',
#   '052',
#   '045',
#   '058',
#   '618',
#   '049',
#   '047',
#   '050',
#   '059',
#   '061',
#   '065',
#   '072',
#   '076',
#   '022',
#   '077',
#   '030',
#   '080',
#   '864',
#   '033',
#   '863',
#   '084',
#   '051',
#   '069',
#   '861',
#   '083',
#   '040',
#   '887',
#   '088',
#   '089',
#   '867',
#   '024',
#   '090',
#   '092',
#   '095',
#   '096',
#   '094',
#   '868',
#   '097',
#   '098',
#   '099',
#   '102',
#   '082',
#   '067',
#   '106',
#   '107',
#   '109',
#   '111',
#   '113',
#   '114',
#   '079',
#   '115',
#   '116',
#   '117'],
#  ['017', '064', '858', '403'],
#  ['402', '021', '606', '002'],
#  ['005', '036', '035', '002'],
#  ['054',
#   '031',
#   '008',
#   '864',
#   '002',
#   '085',
#   '857',
#   '024',
#   '861',
#   '025',
#   '089',
#   '869'],
#  ['003', '005', '010', '005', '5'],
#  ['055', '002'],
#  ['004', '003', '070'],
#  ['002', '004', '062', '007', '055', '070', '007'],
#  ['002', '606', '009', '005', '403'],
#  ['002', '009', '033'],
#  ['003', '035', '012'],
#  ['002',
#   '865',
#   '017',
#   '077',
#   '005',
#   '026',
#   '864',
#   '009',
#   '061',
#   '084',
#   '053',
#   '832',
#   '025',
#   '021',
#   '026',
#   '022',
#   '027'],
#  ['115', '586', '015', '009'],
#  ['005', '059', '610'],
#  ['002',
#   '009',
#   '021',
#   '069',
#   '055',
#   '030',
#   '046',
#   '003',
#   '024',
#   '022',
#   '005',
#   '017',
#   '072',
#   '025',
#   '056',
#   '068',
#   '073',
#   '019',
#   '091',
#   '092',
#   '825',
#   '097'],
#  ['030',
#   '028',
#   '051',
#   '018',
#   '052',
#   '818',
#   '049',
#   '062',
#   '060',
#   '005',
#   '064',
#   '025'],
#  ['109',
#   '108',
#   '106',
#   '104',
#   '103',
#   '102',
#   '100',
#   '097',
#   '095',
#   '091',
#   '008',
#   '002',
#   '005',
#   '402',
#   '610'],
#  ['009', '005', '827', '610'],
#  ['002', '009', '017', '046', '057', '622', '827', '033', '031', '073', '025'],
#  ['055', '002', '002'],
#  ['055', '055', '619', '118'],
#  ['005',
#   '003',
#   '002',
#   '009',
#   '621',
#   '009',
#   '002',
#   '008',
#   '128',
#   '125',
#   '122',
#   '640',
#   '002',
#   '002',
#   '011'],
#  ['007', '655', '007'],
#  ['009',
#   '002',
#   '006',
#   '008',
#   '017',
#   '019',
#   '018',
#   '016',
#   '054',
#   '031',
#   '029',
#   '027',
#   '025',
#   '023',
#   '021',
#   '020',
#   '069',
#   '066',
#   '058',
#   '056',
#   '053',
#   '052',
#   '051',
#   '032',
#   '030',
#   '072',
#   '068',
#   '029',
#   '027',
#   '026',
#   '024',
#   '033',
#   '031',
#   '100',
#   '111',
#   '504',
#   '119'],
#  ['055', '008', '021', '040', '009', '015', '002'],
#  ['002', '587', '018', '061'],
#  ['017',
#   '027',
#   '032',
#   '052',
#   '819',
#   '820',
#   '862',
#   '866',
#   '864',
#   '887',
#   '869',
#   '122',
#   '025'],
#  ['017',
#   '002',
#   '011',
#   '018',
#   '030',
#   '025',
#   '016',
#   '009',
#   '025',
#   '040',
#   '070',
#   '001',
#   '031',
#   '046',
#   '029',
#   '051',
#   '032',
#   '008',
#   '053',
#   '056',
#   '057',
#   '055',
#   '068',
#   '012',
#   '079',
#   '065',
#   '098',
#   '107',
#   '117',
#   '122',
#   '128',
#   '132',
#   '017',
#   '009',
#   '002'],
#  ['005', '002', '002', '003', '001', '007', '005', '001', '022'],
#  ['002', '009', '055', '017', '015'],
#  ['857', '002', '009', '590', '017', '018'],
#  ['005', '016', '009', '023', '002', '008', '027', '025'],
#  ['002', '055', '008', '646'],
#  ['015', '009', '610', '005'],
#  ['005', '003', '001'],
#  ['009', '005', '009', '005', '009', '005', '069', '070'],
#  ['403', '002', '622', '016'],
#  ['005', '005', '403'],
#  ['007', '003', '655', '061'],
#  ['004', '005', '003'],
#  ['005', '003', '014'],
#  ['403', '005', '653'],
#  ['005', '008', '024', '001'],
#  ['070', '001', '004', '010'],
#  ['005', '003', '112'],
#  ['006', '002', '009', '501'],
#  ['007', '036', '002'],
#  ['615', '002', '009'],
#  ['008', '055', '009'],
#  ['005', '002', '009', '622'],
#  ['016',
#   '009',
#   '005',
#   '022',
#   '022',
#   '020',
#   '020',
#   '002',
#   '002',
#   '029',
#   '025',
#   '025'],
#  ['002', '003', '005'],
#  ['002', '009', '005', '021', '059', '610'],
#  ['517', '055'],
#  ['653', '005', '883'],
#  ['002', '055', '832', '513', '868'],
#  ['511', '006', '002', '052', '058', '006', '003', '126', '125', '073', '069'],
#  ['005', '403', '002'],
#  ['002', '055', '020', '065', '862', '080', '085'],
#  ['002', '005', '003', '027', '007', '126'],
#  ['107', '612', '127', '060'],
#  ['002', '005', '072', '003', '077', '018'],
#  ['005', '007', '403', '002', '558', '007', '559'],
#  ['015', '009', '002'],
#  ['005', '003', '002', '035', '008', '070', '049'],
#  ['008', '009', '055', '002', '050', '069', '610'],
#  ['002', '005', '009', '625', '021', '008', '108'],
#  ['046', '027', '020', '002', '009', '049', '050', '059', '20'],
#  ['011', '041', '002', '023', '016', '624', '024', '021', '018'],
#  ['009', '002', '015', '005'],
#  ['402',
#   '607',
#   '002',
#   '009',
#   '003',
#   '026',
#   '024',
#   '023',
#   '026',
#   '005',
#   '046',
#   '024',
#   '031',
#   '001',
#   '052'],
#  ['009',
#   '027',
#   '026',
#   '610',
#   '102',
#   '029',
#   '107',
#   '033',
#   '030',
#   '109',
#   '031',
#   '028',
#   '002',
#   '072',
#   '069',
#   '066',
#   '120',
#   '032'],
#  ['009',
#   '002',
#   '005',
#   '024',
#   '022',
#   '041',
#   '026',
#   '008',
#   '013',
#   '018',
#   '003',
#   '046',
#   '027',
#   '030',
#   '055',
#   '052',
#   '30',
#   '045',
#   '056',
#   '017',
#   '058',
#   '049',
#   '059',
#   '060',
#   '061',
#   '062',
#   '057',
#   '063',
#   '064',
#   '065',
#   '066',
#   '050',
#   '036',
#   '033',
#   '067',
#   '068',
#   '827',
#   '025',
#   '071',
#   '011',
#   '069',
#   '856',
#   '031',
#   '029',
#   '072',
#   '022',
#   '073',
#   '023',
#   '021',
#   '026',
#   '030',
#   '009',
#   '028',
#   '862',
#   '016',
#   '074',
#   '070',
#   '075',
#   '053',
#   '852',
#   '076',
#   '046',
#   '055',
#   '077',
#   '003',
#   '002',
#   '860',
#   '079',
#   '080',
#   '051',
#   '032',
#   '606',
#   '864',
#   '081',
#   '054',
#   '863',
#   '084',
#   '085',
#   '832',
#   '855',
#   '082',
#   '083',
#   '086',
#   '023',
#   '861',
#   '087',
#   '006',
#   '040',
#   '019',
#   '017',
#   '088',
#   '885',
#   '886',
#   '089',
#   '072',
#   '090'],
#  ['055', '005', '002', '009', '002', '008'],
#  ['003', '033', '031', '008', '009', '019', '101', '117'],
#  ['055',
#   '054',
#   '024',
#   '005',
#   '008',
#   '011',
#   '827',
#   '001',
#   '002',
#   '046',
#   '863',
#   '009',
#   '004',
#   '861',
#   '086',
#   '083',
#   '867',
#   '887',
#   '869',
#   '025',
#   '027',
#   '021',
#   '033',
#   '089',
#   '020',
#   '884',
#   '003',
#   '010',
#   '079',
#   '096',
#   '098'],
#  ['002', '005', '009'],
#  ['002', '009', '006', '002', '008', '018', '016'],
#  ['001',
#   '002',
#   '016',
#   '003',
#   '041',
#   '036',
#   '008',
#   '800',
#   '018',
#   '611',
#   '012',
#   '517',
#   '027',
#   '030',
#   '517',
#   '052',
#   '049',
#   '30',
#   '517',
#   '009',
#   '002',
#   '055',
#   '055',
#   '517',
#   '082',
#   '009',
#   '002',
#   '611',
#   '028',
#   '088',
#   '002',
#   '021',
#   '002',
#   '069',
#   '002',
#   '046',
#   '024',
#   '009',
#   '055',
#   '020',
#   '058',
#   '002',
#   '055',
#   '008',
#   '514',
#   '092',
#   '094',
#   '002',
#   '009',
#   '106',
#   '002',
#   '141'],
#  ['002', '005', '818'],
#  ['002', '069', '055', '005'],
#  ['402', '009', '612', '005'],
#  ['403', '006', '511'],
#  ['003', '005', '001'],
#  ['017', '023', '022', '024', '028', '056', '067', '827', '079', '040'],
#  ['020', '820', '069', '886'],
#  ['006', '002', '018'],
#  ['004', '001', '070'],
#  ['055', '002'],
#  ['016', '023', '021', '030', '30'],
#  ['014', '003', '008'],
#  ['005', '403', '004', '001'],
#  ['003', '005', '010'],
#  ['011', '002', '003'],
#  ['118',
#   '116',
#   '121',
#   '119',
#   '121',
#   '121',
#   '126',
#   '126',
#   '031',
#   '029',
#   '027',
#   '819',
#   '017',
#   '009',
#   '002',
#   '009'],
#  ['403', '005', '055', '009', '002'],
#  ['005', '003', '009'],
#  ['002', '008', '089', '009'],
#  ['008',
#   '002',
#   '003',
#   '019',
#   '026',
#   '022',
#   '061',
#   '010',
#   '076',
#   '079',
#   '100',
#   '864',
#   '113',
#   '116',
#   '121',
#   '884'],
#  ['005',
#   '009',
#   '002',
#   '005',
#   '055',
#   '008',
#   '026',
#   '024',
#   '022',
#   '019',
#   '020',
#   '021',
#   '020',
#   '001',
#   '017',
#   '018',
#   '003',
#   '004'],
#  ['003', '005', '012'],
#  ['002', '019', '005', '009'],
#  ['022', '009', '046', '068'],
#  ['402', '009', '002', '123', '113', '016', '114'],
#  ['003', '012', '010', '014', '001', '005'],
#  ['003', '005', '035', '001', '805', '834', '005', '014', '005', '005'],
#  ['403', '007', '014', '084', '079', '077'],
#  ['035', '003'],
#  ['040',
#   '003',
#   '025',
#   '031',
#   '004',
#   '001',
#   '005',
#   '006',
#   '048',
#   '050',
#   '531',
#   '018',
#   '070',
#   '024',
#   '027',
#   '033',
#   '869',
#   '010',
#   '079',
#   '089',
#   '117',
#   '119',
#   '031'],
#  ['009',
#   '041',
#   '033',
#   '002',
#   '002',
#   '021',
#   '533',
#   '086',
#   '009',
#   '027',
#   '057',
#   '033',
#   '073',
#   '016',
#   '073',
#   '002',
#   '025',
#   '055',
#   '073',
#   '884',
#   '020',
#   '069',
#   '027',
#   '068',
#   '046',
#   '085',
#   '027',
#   '009',
#   '107',
#   '046'],
#  ['003', '035'],
#  ['002', '002', '099', '610'],
#  ['003', '035', '005', '007', '009', '009'],
#  ['403', '005', '012', '014', '026'],
#  ['002',
#   '009',
#   '005',
#   '606',
#   '800',
#   '003',
#   '028',
#   '055',
#   '032',
#   '020',
#   '049',
#   '036',
#   '062',
#   '071'],
#  ['832',
#   '832',
#   '832',
#   '832',
#   '031',
#   '031',
#   '031',
#   '031',
#   '002',
#   '606',
#   '009',
#   '026',
#   '610',
#   '002',
#   '019'],
#  ['403', '403', '001'],
#  ['005', '003', '531', '002', '009'],
#  ['005', '108', '002', '009'],
#  ['002', '015', '009', '040'],
#  ['009', '009', '629', '009', '003', '077', '001', '003', '009'],
#  ['002', '611', '002'],
#  ['003', '008', '004'],
#  ['002', '009', '008', '009', '002', '002'],
#  ['017',
#   '046',
#   '029',
#   '030',
#   '009',
#   '002',
#   '032',
#   '051',
#   '055',
#   '30',
#   '049',
#   '059',
#   '064',
#   '065',
#   '066',
#   '040',
#   '050',
#   '068',
#   '023',
#   '862',
#   '074',
#   '020',
#   '025',
#   '081',
#   '027',
#   '061',
#   '028',
#   '088',
#   '033',
#   '057',
#   '069'],
#  ['024', '24', '008', '025', '002', '026'],
#  ['403',
#   '402',
#   '009',
#   '008',
#   '005',
#   '015',
#   '052',
#   '051',
#   '045',
#   '006',
#   '015',
#   '057',
#   '020'],
#  ['003', '010', '004'],
#  ['002', '016', '040', '041', '019', '011', '026', '025', '027'],
#  ['008',
#   '009',
#   '102',
#   '113',
#   '114',
#   '079',
#   '857',
#   '118',
#   '119',
#   '121',
#   '122',
#   '124',
#   '126',
#   '127',
#   '131',
#   '801'],
#  ['001', '045', '530'],
#  ['126', '587', '002', '008', '584', '009'],
#  ['005',
#   '002',
#   '036',
#   '021',
#   '020',
#   '031',
#   '029',
#   '028',
#   '606',
#   '614',
#   '018',
#   '069',
#   '072',
#   '054',
#   '027',
#   '025',
#   '024',
#   '857',
#   '068',
#   '065',
#   '066',
#   '030',
#   '046',
#   '033',
#   '023',
#   '861',
#   '060',
#   '055',
#   '017',
#   '015',
#   '026',
#   '016',
#   '010',
#   '058',
#   '057',
#   '045',
#   '052',
#   '032',
#   '051',
#   '003',
#   '008'],
#  ['025', '002', '033', '046', '062', '009', '026', '002', '002', '089'],
#  ['002',
#   '009',
#   '005',
#   '055',
#   '016',
#   '118',
#   '117',
#   '403',
#   '073',
#   '028',
#   '002',
#   '022',
#   '552',
#   '002',
#   '126',
#   '022',
#   '029',
#   '008',
#   '009',
#   '009',
#   '006',
#   '002',
#   '005',
#   '403',
#   '403'],
#  ['035', '011'],
#  ['004', '005', '012', '003', '003', '001', '005', '004', '001'],
#  ['106', '653', '055', '020', '002', '012', '018', '016', '002', '111'],
#  ['041',
#   '009',
#   '002',
#   '008',
#   '046',
#   '827',
#   '062',
#   '049',
#   '025',
#   '864',
#   '081',
#   '061',
#   '060',
#   '023',
#   '021'],
#  ['403', '403', '004'],
#  ['007', '565', '005', '014', '003'],
#  ['002', '005', '007', '007'],
#  ['002',
#   '622',
#   '009',
#   '005',
#   '055',
#   '017',
#   '016',
#   '018',
#   '016',
#   '030',
#   '020',
#   '011',
#   '021',
#   '056',
#   '068',
#   '033',
#   '031',
#   '029',
#   '025',
#   '032',
#   '065',
#   '045',
#   '046',
#   '024',
#   '051',
#   '052',
#   '053',
#   '005',
#   '057',
#   '058',
#   '060',
#   '069',
#   '072',
#   '073',
#   '079',
#   '027',
#   '090',
#   '084',
#   '085',
#   '091',
#   '095',
#   '096',
#   '088',
#   '093',
#   '094',
#   '097',
#   '098',
#   '092',
#   '001',
#   '099',
#   '101',
#   '013',
#   '102',
#   '105',
#   '106',
#   '082',
#   '067',
#   '107',
#   '108',
#   '110',
#   '113',
#   '114'],
#  ['005', '403', '026', '024'],
#  ['008', '003', '002'],
#  ['026', '005', '5'],
#  ['005', '009', '002', '028', '032', '033', '031', '015', '055'],
#  ['009', '002', '027', '025'],
#  ['622', '041', '805'],
#  ['005',
#   '008',
#   '009',
#   '002',
#   '009',
#   '002',
#   '403',
#   '036',
#   '022',
#   '024',
#   '015',
#   '060',
#   '058',
#   '033',
#   '031',
#   '029',
#   '050',
#   '046',
#   '024',
#   '071',
#   '057'],
#  ['002', '004', '001', '016', '068', '055', '018', '054', '861', '609', '085'],
#  ['403', '005', '035', '35'],
#  ['046',
#   '017',
#   '018',
#   '18',
#   '064',
#   '063',
#   '062',
#   '858',
#   '067',
#   '024',
#   '071',
#   '057',
#   '021',
#   '061',
#   '085',
#   '025',
#   '021',
#   '017'],
#  ['005', '004', '001'],
#  ['009', '008', '002', '022', '531', '023'],
#  ['009', '002', '069', '027', '025', '024', '008', '885', '026', '128', '129'],
#  ['008', '009', '003'],
#  ['012', '005', '002', '122'],
#  ['015', '091', '093', '105'],
#  ['002',
#   '016',
#   '108',
#   '106',
#   '106',
#   '002',
#   '109',
#   '107',
#   '105',
#   '103',
#   '100',
#   '099',
#   '623',
#   '005',
#   '111',
#   '108',
#   '118',
#   '116',
#   '114'],
#  ['014', '003', '005', '005'],
#  ['008', '009', '100'],
#  ['002', '613', '403', '126', '874', '133', '141'],
#  ['017', '016', '021', '103', '126'],
#  ['002', '586', '009', '008', '027', '130', '020', '005'],
#  ['610', '009', '103', '102', '001'],
#  ['009', '005', '610', '027', '036', '002'],
#  ['108', '106', '649', '402', '016', '651'],
#  ['002', '003', '040', '008', '010', '002', '055'],
#  ['002',
#   '013',
#   '008',
#   '009',
#   '113',
#   '111',
#   '061',
#   '114',
#   '100',
#   '125',
#   '126',
#   '129',
#   '126',
#   '132',
#   '133',
#   '025'],
#  ['036', '006', '511'],
#  ['010', '005', '005', '003'],
#  ['006', '531', '002'],
#  ['055',
#   '002',
#   '009',
#   '008',
#   '098',
#   '015',
#   '054',
#   '018',
#   '017',
#   '016',
#   '403',
#   '100',
#   '099',
#   '586',
#   '102',
#   '101',
#   '021',
#   '020',
#   '019',
#   '072',
#   '108',
#   '107',
#   '106',
#   '104',
#   '109',
#   '105',
#   '114',
#   '113',
#   '111',
#   '053',
#   '056',
#   '118',
#   '116',
#   '119',
#   '126',
#   '124',
#   '122',
#   '120',
#   '123',
#   '003',
#   '069',
#   '066',
#   '060',
#   '589'],
#  ['016', '018', '020', '021', '007', '002', '005', '022', '084'],
#  ['016', '002', '017'],
#  ['103',
#   '514',
#   '009',
#   '100',
#   '002',
#   '026',
#   '008',
#   '005',
#   '079',
#   '117',
#   '089',
#   '118',
#   '025',
#   '119',
#   '102',
#   '027',
#   '121',
#   '031'],
#  ['402', '402', '002', '009', '013'],
#  ['001', '003', '005', '004'],
#  ['015', '009', '054', '016'],
#  ['009', '002', '016'],
#  ['005', '009', '018'],
#  ['873',
#   '523',
#   '002',
#   '009',
#   '855',
#   '115',
#   '113',
#   '055',
#   '002',
#   '008',
#   '019',
#   '115',
#   '033',
#   '523',
#   '055',
#   '002',
#   '002',
#   '121'],
#  ['005', '003', '512', '587'],
#  ['003', '012', '005'],
#  ['002', '563', '005'],
#  ['027', '056', '622'],
#  ['077', '069', '055', '046'],
#  ['403', '014', '001', '010'],
#  ['076', '625', '009'],
#  ['005', '005', '005', '005', '007', '007', '007', '007', '655'],
#  ['055', '006', '002', '009', '002', '009', '511'],
#  ['003', '005', '010'],
#  ['007', '655', '002', '005', '028'],
#  ['002', '586', '009'],
#  ['003', '004', '005', '012'],
#  ['002', '018', '024', '046', '025', '017', '25', '052'],
#  ['403', '002', '008', '002', '653', '005', '004'],
#  ['009',
#   '016',
#   '002',
#   '008',
#   '018',
#   '017',
#   '019',
#   '026',
#   '045',
#   '058',
#   '063',
#   '025',
#   '020'],
#  ['036',
#   '002',
#   '009',
#   '035',
#   '016',
#   '041',
#   '018',
#   '024',
#   '020',
#   '026',
#   '622',
#   '021',
#   '046',
#   '027',
#   '029',
#   '025',
#   '028',
#   '032',
#   '052',
#   '051',
#   '050',
#   '005',
#   '061',
#   '063',
#   '062',
#   '065',
#   '060',
#   '024',
#   '067',
#   '068',
#   '831',
#   '072',
#   '069',
#   '862',
#   '074',
#   '075',
#   '022',
#   '021',
#   '024',
#   '025',
#   '026',
#   '027',
#   '080',
#   '864',
#   '077',
#   '072',
#   '084',
#   '085',
#   '046',
#   '051',
#   '052',
#   '082',
#   '083',
#   '056',
#   '023',
#   '861',
#   '065',
#   '087',
#   '068',
#   '072',
#   '073',
#   '085',
#   '867',
#   '861',
#   '867',
#   '869',
#   '881',
#   '884',
#   '885',
#   '016',
#   '002',
#   '017',
#   '018',
#   '028',
#   '031',
#   '006',
#   '056'],
#  ['002', '402', '622'],
#  ['056', '009', '064', '002', '002'],
#  ['002', '009', '017', '005'],
#  ['036', '016', '041', '009', '030', '610', '071', '076', '080'],
#  ['004', '005', '003'],
#  ['009', '005', '625', '629'],
#  ['045', '610', '009'],
#  ['611',
#   '002',
#   '009',
#   '097',
#   '610',
#   '095',
#   '091',
#   '085',
#   '079',
#   '018',
#   '015',
#   '016',
#   '019',
#   '065',
#   '100',
#   '008',
#   '005'],
#  ['005',
#   '002',
#   '006',
#   '076',
#   '009',
#   '056',
#   '053',
#   '052',
#   '051',
#   '032',
#   '030',
#   '046',
#   '024',
#   '022',
#   '501',
#   '020',
#   '018',
#   '017',
#   '081',
#   '085',
#   '832',
#   '073',
#   '082'],
#  ['009',
#   '021',
#   '018',
#   '046',
#   '011',
#   '017',
#   '016',
#   '028',
#   '031',
#   '051',
#   '045',
#   '609',
#   '049',
#   '050',
#   '059',
#   '060',
#   '061',
#   '064',
#   '065',
#   '066',
#   '009',
#   '050',
#   '067',
#   '068',
#   '831',
#   '827',
#   '069',
#   '016',
#   '071',
#   '073',
#   '057',
#   '023',
#   '002',
#   '074',
#   '075',
#   '076',
#   '056',
#   '022',
#   '065',
#   '016',
#   '085',
#   '082',
#   '857',
#   '002',
#   '085',
#   '609',
#   '040',
#   '088',
#   '887',
#   '885',
#   '016',
#   '009',
#   '621',
#   '016',
#   '088',
#   '861',
#   '881',
#   '016',
#   '028',
#   '090',
#   '092',
#   '096',
#   '094',
#   '872',
#   '097',
#   '102',
#   '016',
#   '104',
#   '082',
#   '067',
#   '092',
#   '621',
#   '093',
#   '016',
#   '111',
#   '114',
#   '115',
#   '088',
#   '873',
#   '122',
#   '125',
#   '621'],
#  ['008',
#   '002',
#   '009',
#   '831',
#   '887',
#   '084',
#   '124',
#   '118',
#   '117',
#   '026',
#   '024',
#   '046',
#   '116',
#   '115',
#   '003',
#   '005',
#   '114',
#   '107',
#   '819',
#   '011'],
#  ['002', '009', '028', '027'],
#  ['005', '003', '002', '639'],
#  ['002', '002', '002', '002', '009', '009', '009', '009'],
#  ['007', '403', '005'],
#  ['010', '003', '004'],
#  ['002', '002', '009', '002', '008', '009'],
#  ['005', '003', '003', '005'],
#  ['055', '009', '652', '005'],
#  ['002', '110', '020', '018', '130', '029'],
#  ['055', '009', '015'],
#  ['009', '821', '019', '873', '017'],
#  ['403', '001', '035', '004'],
#  ['055', '055'],
#  ['002', '610', '005', '008'],
#  ['003', '001', '004'],
#  ['005', '003', '070', '010'],
#  ['054',
#   '013',
#   '002',
#   '003',
#   '005',
#   '062',
#   '060',
#   '056',
#   '018',
#   '017',
#   '077',
#   '860',
#   '077',
#   '020',
#   '011',
#   '610',
#   '080',
#   '864',
#   '079',
#   '072',
#   '061',
#   '030',
#   '084',
#   '022',
#   '832',
#   '085',
#   '083',
#   '009',
#   '025',
#   '015',
#   '086',
#   '028',
#   '026',
#   '040',
#   '033',
#   '045',
#   '088',
#   '881',
#   '073',
#   '065',
#   '066'],
#  ['003', '005', '867', '610', '111'],
#  ['029', '005', '004', '066', '016', '079', '009'],
#  ['402', '543', '128'],
#  ['010', '035', '403', '005', '001', '070'],
#  ['002', '653', '081'],
#  ['002',
#   '009',
#   '008',
#   '611',
#   '017',
#   '403',
#   '033',
#   '029',
#   '016',
#   '021',
#   '027',
#   '026',
#   '024',
#   '031',
#   '006',
#   '009',
#   '101',
#   '022',
#   '002',
#   '056',
#   '027',
#   '026',
#   '018',
#   '104',
#   '103',
#   '005',
#   '072',
#   '105',
#   '030',
#   '017',
#   '106',
#   '005',
#   '109',
#   '029'],
#  ['003', '113', '111'],
#  ['510', '002', '622'],
#  ['005', '007', '403'],
#  ['005',
#   '002',
#   '022',
#   '020',
#   '016',
#   '036',
#   '024',
#   '017',
#   '030',
#   '027',
#   '611',
#   '009',
#   '028',
#   '046',
#   '032',
#   '051',
#   '056',
#   '019',
#   '057',
#   '058',
#   '049',
#   '059',
#   '30',
#   '27',
#   '611',
#   '060',
#   '063',
#   '067'],
#  ['017', '009', '002'],
#  ['002', '009', '005', '403'],
#  ['002', '018', '578'],
#  ['884',
#   '869',
#   '066',
#   '103',
#   '013',
#   '013',
#   '015',
#   '114',
#   '113',
#   '111',
#   '110',
#   '108',
#   '106',
#   '887',
#   '013',
#   '119',
#   '116',
#   '115'],
#  ['834', '016', '002', '005'],
#  ['006', '002', '009'],
#  ['005', '003', '002'],
#  ['023', '002', '017', '002', '086', '009'],
#  ['003', '005', '012', '001', '010', '014'],
#  ['002',
#   '090',
#   '018',
#   '017',
#   '016',
#   '009',
#   '015',
#   '008',
#   '020',
#   '019',
#   '091',
#   '021',
#   '092',
#   '095',
#   '013',
#   '054',
#   '098',
#   '097',
#   '006',
#   '002',
#   '009',
#   '099',
#   '606',
#   '102',
#   '101',
#   '103',
#   '105',
#   '610',
#   '104',
#   '866',
#   '005',
#   '403'],
#  ['009', '614', '023', '886', '110'],
#  ['005', '004', '003', '014'],
#  ['818', '606', '011'],
#  ['002', '007', '006'],
#  ['002', '013', '020', '018', '002', '009', '072'],
#  ['003', '005', '112'],
#  ['002',
#   '009',
#   '610',
#   '098',
#   '095',
#   '091',
#   '015',
#   '403',
#   '008',
#   '011',
#   '016',
#   '097',
#   '055',
#   '054',
#   '099',
#   '013',
#   '100',
#   '018',
#   '107',
#   '072',
#   '068',
#   '103',
#   '104'],
#  ['402', '017', '611'],
#  ['122', '122', '119', '121', '117'],
#  ['055',
#   '009',
#   '622',
#   '002',
#   '068',
#   '055',
#   '009',
#   '054',
#   '095',
#   '002',
#   '868',
#   '052',
#   '054',
#   '097',
#   '101',
#   '002',
#   '069',
#   '082',
#   '114',
#   '116'],
#  ['002', '008', '009', '005'],
#  ['036', '005', '016', '010', '024', '051', '24'],
#  ['002', '009', '002', '009', '002', '009', '002', '009', '002'],
#  ['016',
#   '088',
#   '029',
#   '024',
#   '031',
#   '090',
#   '097',
#   '005',
#   '065',
#   '027',
#   '115',
#   '022',
#   '122',
#   '062',
#   '121',
#   '127'],
#  ['003', '002', '005'],
#  ['002', '024', '022', '020', '018', '016', '009', '046', '059', '050'],
#  ['011', '072', '065', '118'],
#  ['004', '005', '003'],
#  ['007', '403', '010'],
#  ['831', '005', '005'],
#  ['003', '010', '005', '001'],
#  ['005', '104', '619', '009', '002', '109', '107'],
#  ['002', '009', '002', '009'],
#  ['402', '009', '611', '127'],
#  ['622', '036', '017', '023', '028', '032', '052', '059'],
#  ['613', '036', '015', '006', '016', '019'],
#  ['015',
#   '110',
#   '108',
#   '112',
#   '403',
#   '005',
#   '011',
#   '101',
#   '118',
#   '114',
#   '113',
#   '002',
#   '115',
#   '122',
#   '119',
#   '133',
#   '883',
#   '874'],
#  ['023',
#   '002',
#   '002',
#   '046',
#   '024',
#   '008',
#   '625',
#   '009',
#   '017',
#   '025',
#   '021',
#   '019',
#   '031',
#   '030',
#   '029'],
#  ['008', '012', '024', '057', '027', '008'],
#  ['800', '018', '033', '031', '048', '029', '002', '019', '079', '824'],
#  ['403', '005', '002'],
#  ['003', '005', '001'],
#  ['005',
#   '009',
#   '002',
#   '403',
#   '007',
#   '001',
#   '006',
#   '054',
#   '031',
#   '029',
#   '027',
#   '025',
#   '016',
#   '014',
#   '010',
#   '017',
#   '008',
#   '018',
#   '019',
#   '006',
#   '015',
#   '069',
#   '066',
#   '058',
#   '057',
#   '045',
#   '053',
#   '051',
#   '032',
#   '031',
#   '030',
#   '046',
#   '024',
#   '025',
#   '020',
#   '028',
#   '026',
#   '027',
#   '033',
#   '028',
#   '021',
#   '020',
#   '013',
#   '022',
#   '653',
#   '017',
#   '073',
#   '072',
#   '068',
#   '065',
#   '066',
#   '060',
#   '058',
#   '058',
#   '056',
#   '052',
#   '051',
#   '051',
#   '006',
#   '007',
#   '046',
#   '026',
#   '023',
#   '056',
#   '027',
#   '090',
#   '084',
#   '079',
#   '085',
#   '091',
#   '094',
#   '093',
#   '825',
#   '879',
#   '872',
#   '868',
#   '068',
#   '096',
#   '079',
#   '073',
#   '098',
#   '098',
#   '066',
#   '099',
#   '100',
#   '104',
#   '102',
#   '864',
#   '106',
#   '107',
#   '090',
#   '092',
#   '112',
#   '093',
#   '094',
#   '113',
#   '114',
#   '079',
#   '097',
#   '098',
#   '116',
#   '115',
#   '099',
#   '117',
#   '101',
#   '088',
#   '089',
#   '821',
#   '019',
#   '873',
#   '855',
#   '110',
#   '030',
#   '118',
#   '111',
#   '108',
#   '119',
#   '112',
#   '114',
#   '120',
#   '121',
#   '122',
#   '123',
#   '007',
#   '009'],
#  ['002', '009', '639', '027'],
#  ['831',
#   '016',
#   '887',
#   '002',
#   '008',
#   '009',
#   '120',
#   '116',
#   '113',
#   '111',
#   '108',
#   '122',
#   '124',
#   '123',
#   '117',
#   '115',
#   '114',
#   '107',
#   '102',
#   '100',
#   '099',
#   '101',
#   '006',
#   '015',
#   '007',
#   '011',
#   '121',
#   '119',
#   '653',
#   '046',
#   '025',
#   '024',
#   '022',
#   '033',
#   '031',
#   '023',
#   '018',
#   '026',
#   '125',
#   '005',
#   '013',
#   '069',
#   '126',
#   '017',
#   '027',
#   '055',
#   '029',
#   '020',
#   '019',
#   '030'],
#  ['002', '009', '002', '003'],
#  ['403', '005', '014'],
#  ['002', '009', '403'],
#  ['004',
#   '086',
#   '402',
#   '627',
#   '069',
#   '025',
#   '885',
#   '028',
#   '046',
#   '032',
#   '016',
#   '623',
#   '057',
#   '627'],
#  ['002', '008', '026', '045', '062', '060', '058', '063', '064', '069', '068'],
#  ['005', '015', '028', '021', '818', '403'],
#  ['009',
#   '002',
#   '008',
#   '015',
#   '055',
#   '016',
#   '011',
#   '017',
#   '090',
#   '084',
#   '091',
#   '085',
#   '073',
#   '069',
#   '072',
#   '046',
#   '095',
#   '092',
#   '018',
#   '021',
#   '096',
#   '033',
#   '824',
#   '822',
#   '028',
#   '026',
#   '094',
#   '825',
#   '098',
#   '005',
#   '020',
#   '099',
#   '101',
#   '027',
#   '102',
#   '103',
#   '100',
#   '104',
#   '032',
#   '053',
#   '082',
#   '107',
#   '060',
#   '845',
#   '115',
#   '117',
#   '114',
#   '004',
#   '002',
#   '107',
#   '031',
#   '009',
#   '046'],
#  ['005', '003', '014', '010'],
#  ['002', '009', '623', '099', '028', '055'],
#  ['002', '009', '008'],
#  ['005', '002', '009', '008', '009'],
#  ['403', '010', '035', '055'],
#  ['020', '021', '016', '018'],
#  ['002',
#   '032',
#   '057',
#   '050',
#   '061',
#   '072',
#   '023',
#   '073',
#   '069',
#   '074',
#   '076',
#   '005',
#   '084',
#   '855',
#   '066',
#   '881',
#   '016',
#   '017',
#   '024',
#   '030',
#   '009',
#   '079',
#   '004',
#   '089',
#   '022',
#   '095',
#   '092',
#   '872',
#   '102',
#   '109',
#   '115',
#   '117',
#   '033',
#   '121',
#   '132'],
#  ['002', '016', '008'],
#  ['001', '004', '012', '003'],
#  ['011', '029', '046', '032', '057', '058', '061', '084'],
#  ['610',
#   '402',
#   '009',
#   '016',
#   '005',
#   '015',
#   '054',
#   '017',
#   '018',
#   '002',
#   '020',
#   '021',
#   '053',
#   '051',
#   '032',
#   '030',
#   '029',
#   '046',
#   '025',
#   '024',
#   '022',
#   '023',
#   '008',
#   '056',
#   '072',
#   '069',
#   '090',
#   '027',
#   '092',
#   '028',
#   '095',
#   '091',
#   '096',
#   '031',
#   '822',
#   '093',
#   '872',
#   '868',
#   '013',
#   '097',
#   '098',
#   '033',
#   '045',
#   '026',
#   '011',
#   '052',
#   '099',
#   '101',
#   '073',
#   '057',
#   '102',
#   '103',
#   '058',
#   '104',
#   '060',
#   '105',
#   '065',
#   '106',
#   '082',
#   '107',
#   '108'],
#  ['035', '004', '003', '005'],
#  ['059', '611', '002'],
#  ['005', '002', '009'],
#  ['006', '531', '009'],
#  ['002', '403', '511'],
#  ['013', '002', '653'],
#  ['403', '005', '014'],
#  ['078', '003'],
#  ['002',
#   '055',
#   '009',
#   '008',
#   '614',
#   '005',
#   '003',
#   '016',
#   '017',
#   '015',
#   '011',
#   '054',
#   '069',
#   '018',
#   '020',
#   '066',
#   '060',
#   '021',
#   '072',
#   '046',
#   '056',
#   '053',
#   '073',
#   '051',
#   '032',
#   '030',
#   '025',
#   '028',
#   '065',
#   '090',
#   '092',
#   '091',
#   '085',
#   '084',
#   '095',
#   '026',
#   '029',
#   '096',
#   '093',
#   '094',
#   '879',
#   '825',
#   '610',
#   '045',
#   '872',
#   '868',
#   '031',
#   '027',
#   '097',
#   '098',
#   '021',
#   '033',
#   '022',
#   '045',
#   '070',
#   '046',
#   '002',
#   '026',
#   '051',
#   '052',
#   '024',
#   '030',
#   '008',
#   '069',
#   '099',
#   '100',
#   '028',
#   '053',
#   '101',
#   '017',
#   '056',
#   '020',
#   '102',
#   '057',
#   '058',
#   '103',
#   '060',
#   '104',
#   '065',
#   '105',
#   '066',
#   '069',
#   '827',
#   '082',
#   '831',
#   '067',
#   '009',
#   '855',
#   '864',
#   '072',
#   '107',
#   '073',
#   '079',
#   '108',
#   '084',
#   '085',
#   '086',
#   '002',
#   '021',
#   '087',
#   '111',
#   '089',
#   '116',
#   '115',
#   '098',
#   '117',
#   '099',
#   '857',
#   '821',
#   '845',
#   '855',
#   '122',
#   '805',
#   '124',
#   '856',
#   '827'],
#  ['587', '802', '062', '060', '057'],
#  ['002', '008', '003', '008'],
#  ['002', '011', '008', '009', '003', '005', '004'],
#  ['403', '005', '005', '403', '014'],
#  ['402',
#   '107',
#   '403',
#   '009',
#   '008',
#   '105',
#   '100',
#   '099',
#   '096',
#   '005',
#   '055',
#   '095',
#   '091',
#   '097',
#   '103',
#   '100',
#   '097',
#   '112',
#   '010',
#   '113',
#   '111',
#   '110',
#   '109',
#   '107',
#   '106',
#   '106',
#   '105',
#   '114',
#   '114',
#   '106',
#   '111'],
#  ['013', '036', '002', '564', '821', '007'],
#  ['009',
#   '015',
#   '005',
#   '054',
#   '031',
#   '002',
#   '029',
#   '016',
#   '017',
#   '018',
#   '068',
#   '020',
#   '065'],
#  ['009',
#   '031',
#   '019',
#   '046',
#   '026',
#   '008',
#   '005',
#   '025',
#   '024',
#   '029',
#   '029',
#   '002',
#   '027',
#   '072',
#   '019',
#   '073',
#   '021',
#   '055',
#   '031',
#   '032',
#   '002',
#   '623',
#   '009',
#   '053',
#   '015',
#   '003',
#   '090',
#   '058',
#   '060',
#   '095',
#   '066',
#   '033',
#   '093',
#   '022',
#   '825',
#   '879',
#   '097',
#   '098',
#   '084',
#   '025',
#   '100',
#   '029',
#   '087',
#   '102',
#   '089',
#   '002',
#   '091',
#   '856',
#   '094',
#   '109',
#   '031',
#   '079',
#   '118',
#   '120',
#   '002',
#   '112',
#   '026',
#   '122',
#   '025',
#   '121',
#   '884',
#   '124',
#   '031',
#   '129',
#   '051',
#   '032',
#   '132',
#   '133',
#   '002',
#   '022',
#   '834',
#   '872',
#   '025'],
#  ['003', '035'],
#  ['005', '002', '040', '015', '016', '003', '052'],
#  ['005', '072', '005', '009'],
#  ['002', '011', '055'],
#  ['069', '002', '069'],
#  ['002', '009', '653'],
#  ['005', '118', '003'],
#  ['003', '016', '005'],
#  ['002', '606', '008', '085', '084'],
#  ['005', '003', '3'],
#  ['009',
#   '008',
#   '018',
#   '026',
#   '029',
#   '060',
#   '022',
#   '025',
#   '027',
#   '066',
#   '084',
#   '053',
#   '067',
#   '119',
#   '131'],
#  ['014', '003', '005'],
#  ['066', '058', '001', '008', '009', '615', '002'],
#  ['002', '041', '106'],
#  ['002', '005', '085', '079'],
#  ['529', '001', '012'],
#  ['002',
#   '028',
#   '033',
#   '016',
#   '032',
#   '017',
#   '057',
#   '049',
#   '047',
#   '050',
#   '061',
#   '063',
#   '064',
#   '065',
#   '068',
#   '069',
#   '071',
#   '023',
#   '018',
#   '862',
#   '074',
#   '020',
#   '076',
#   '049',
#   '022',
#   '860'],
#  ['056', '587', '003', '005'],
#  ['003', '655', '012'],
#  ['055', '003', '002', '003', '008', '013', '054', '005'],
#  ['055', '403', '002', '008', '070', '874', '001'],
#  ['402',
#   '402',
#   '402',
#   '017',
#   '127',
#   '127',
#   '126',
#   '126',
#   '131',
#   '623',
#   '128',
#   '009',
#   '069',
#   '069'],
#  ['002', '035', '003'],
#  ['009', '606', '002'],
#  ['402', '008', '009'],
#  ['655', '002', '403', '009', '016', '017', '018', '021', '027'],
#  ['403', '035', '005'],
#  ['021', '002', '027'],
#  ['005', '003', '002', '005', '021', '046', '005'],
#  ['003', '005', '864', '070'],
#  ['005', '010', '403'],
#  ['002',
#   '008',
#   '003',
#   '041',
#   '025',
#   '005',
#   '028',
#   '031',
#   '029',
#   '026',
#   '061',
#   '060',
#   '064',
#   '050',
#   '062',
#   '072',
#   '069',
#   '070',
#   '076',
#   '046',
#   '024',
#   '864',
#   '084',
#   '801',
#   '086',
#   '083'],
#  ['002', '009', '586'],
#  ['055', '653'],
#  ['009',
#   '002',
#   '090',
#   '084',
#   '621',
#   '008',
#   '016',
#   '085',
#   '079',
#   '072',
#   '068',
#   '065',
#   '060',
#   '058',
#   '056',
#   '053',
#   '030',
#   '046',
#   '025',
#   '020',
#   '095',
#   '091',
#   '017',
#   '096',
#   '092',
#   '093',
#   '822'],
#  ['002', '015', '079', '072'],
#  ['009', '002', '008', '024', '022', '025', '071', '845'],
#  ['002', '009', '629', '021', '054'],
#  ['002', '403', '005'],
#  ['024', '049', '606'],
#  ['403', '622', '004', '005', '102', '009', '128'],
#  ['403', '001', '005', '004', '014'],
#  ['002', '002', '611', '887'],
#  ['007', '562', '403', '009'],
#  ['402', '403', '653'],
#  ['002',
#   '009',
#   '008',
#   '610',
#   '055',
#   '001',
#   '011',
#   '018',
#   '020',
#   '029',
#   '021',
#   '019',
#   '017',
#   '090',
#   '024',
#   '022',
#   '084',
#   '073',
#   '069',
#   '066',
#   '060',
#   '057',
#   '056',
#   '053',
#   '051',
#   '033',
#   '028',
#   '026',
#   '025',
#   '023',
#   '091',
#   '052',
#   '016',
#   '032',
#   '096',
#   '092',
#   '027',
#   '030',
#   '098',
#   '095',
#   '085',
#   '079',
#   '072',
#   '099',
#   '101',
#   '104',
#   '106',
#   '117',
#   '091'],
#  ['009', '005', '016', '002', '070', '001', '055', '008', '832', '040', '069'],
#  ['002', '009', '054'],
#  ['004',
#   '009',
#   '531',
#   '002',
#   '015',
#   '008',
#   '054',
#   '028',
#   '026',
#   '025',
#   '024',
#   '022',
#   '021',
#   '019',
#   '018',
#   '016',
#   '017',
#   '046',
#   '069',
#   '066',
#   '058',
#   '057',
#   '045',
#   '068',
#   '051',
#   '032',
#   '030',
#   '065',
#   '060',
#   '033',
#   '027',
#   '029',
#   '072',
#   '020',
#   '073',
#   '090',
#   '084',
#   '091',
#   '092',
#   '095',
#   '822',
#   '093',
#   '094',
#   '004',
#   '009',
#   '531',
#   '531',
#   '117',
#   '004',
#   '003',
#   '531',
#   '002',
#   '009',
#   '004'],
#  ['034', '402', '024'],
#  ['003', '005', '001'],
#  ['031', '026', '005', '103'],
#  ['002', '009', '008', '011', '040'],
#  ['402', '040', '017', '622', '074', '083'],
#  ['002',
#   '009',
#   '026',
#   '036',
#   '031',
#   '821',
#   '820',
#   '018',
#   '017',
#   '049',
#   '058',
#   '006',
#   '022',
#   '005',
#   '046',
#   '024',
#   '056',
#   '063',
#   '062',
#   '060',
#   '055',
#   '065',
#   '066',
#   '040',
#   '006',
#   '002',
#   '008',
#   '612',
#   '831',
#   '067',
#   '511',
#   '069',
#   '071',
#   '856',
#   '072',
#   '073',
#   '057',
#   '023',
#   '862',
#   '074',
#   '075',
#   '020',
#   '025',
#   '076',
#   '022',
#   '077',
#   '860',
#   '080',
#   '079',
#   '029',
#   '864',
#   '081',
#   '032',
#   '832',
#   '053',
#   '052',
#   '051',
#   '027',
#   '025',
#   '009',
#   '020',
#   '022',
#   '006',
#   '002',
#   '045',
#   '009',
#   '006',
#   '091',
#   '099',
#   '108',
#   '009',
#   '002',
#   '006',
#   '006',
#   '127',
#   '128'],
#  ['403', '402', '009', '114', '113', '005', '402', '108', '113', '014', '002'],
#  ['005', '625', '016', '855', '008', '070', '053', '002'],
#  ['007', '009', '005', '049'],
#  ['610', '002', '077', '029', '024', '069'],
#  ['055', '009', '015'],
#  ['002', '019', '010', '013', '017', '059', '013'],
#  ['832', '030', '008', '861', '869', '031'],
#  ['002', '009', '007', '005'],
#  ['005', '005', '005', '005'],
#  ['005', '003', '002', '009', '652', '020', '018'],
#  ['002', '006', '507'],
#  ['003', '001', '012', '014', '010'],
#  ['017', '800', '052', '032', '026', '009', '072', '022', '860', '079'],
#  ['005', '403', '010', '014'],
#  ['002', '015', '403', '005'],
#  ['005', '004', '001', '004'],
#  ['514', '008', '002', '003', '005', '009', '018'],
#  ['005',
#   '008',
#   '009',
#   '402',
#   '050',
#   '069',
#   '017',
#   '004',
#   '073',
#   '001',
#   '066',
#   '046',
#   '024',
#   '022',
#   '023',
#   '072',
#   '031',
#   '074',
#   '062',
#   '002',
#   '012',
#   '026',
#   '864',
#   '084',
#   '040'],
#  ['007', '009', '558'],
#  ['031', '008', '610', '002', '032', '003', '055', '531'],
#  ['002', '403', '005', '070', '001', '012'],
#  ['403', '005', '014', '005'],
#  ['007', '008', '563', '007', '403', '090'],
#  ['005', '003', '001'],
#  ['403', '014', '403', '14'],
#  ['040',
#   '022',
#   '016',
#   '030',
#   '056',
#   '075',
#   '021',
#   '024',
#   '085',
#   '881',
#   '029',
#   '031'],
#  ['565', '007', '046', '010', '073', '018'],
#  ['005', '002', '403'],
#  ['010', '005', '403', '002', '009', '013'],
#  ['094',
#   '872',
#   '017',
#   '014',
#   '016',
#   '097',
#   '002',
#   '015',
#   '005',
#   '029',
#   '003',
#   '026',
#   '021'],
#  ['003', '001', '035', '004', '005'],
#  ['403', '005', '403', '001', '004'],
#  ['012', '001', '402'],
#  ['002',
#   '011',
#   '009',
#   '035',
#   '036',
#   '016',
#   '018',
#   '017',
#   '023',
#   '622',
#   '025',
#   '622',
#   '046',
#   '622',
#   '009',
#   '002',
#   '057',
#   '045',
#   '622',
#   '027',
#   '023',
#   '021',
#   '074',
#   '068',
#   '065',
#   '860'],
#  ['019', '001', '005', '008', '024'],
#  ['103', '611', '002', '117', '115', '123', '114'],
#  ['002', '002', '002', '002'],
#  ['002', '028', '027', '047'],
#  ['403', '005', '004', '001', '005', '001'],
#  ['002', '009', '018', '021'],
#  ['094', '020', '018', '027', '009'],
#  ['002', '009', '005'],
#  ['005',
#   '004',
#   '001',
#   '003',
#   '008',
#   '009',
#   '002',
#   '036',
#   '018',
#   '862',
#   '002',
#   '070',
#   '005',
#   '086',
#   '008',
#   '083'],
#  ['005',
#   '002',
#   '009',
#   '021',
#   '824',
#   '098',
#   '097',
#   '102',
#   '103',
#   '104',
#   '106',
#   '046',
#   '107',
#   '108',
#   '109',
#   '110',
#   '113',
#   '024',
#   '115',
#   '088',
#   '117',
#   '126',
#   '127',
#   '128',
#   '130',
#   '047'],
#  ['402', '005', '009'],
#  ['005', '006', '018', '883', '874', '874'],
#  ['016', '026', '024', '062', '063', '065', '005', '860', '022'],
#  ['055', '587', '055', '003'],
#  ['002', '016', '018', '073', '020'],
#  ['050', '062', '009', '002'],
#  ['002', '049', '045'],
#  ['402',
#   '118',
#   '002',
#   '016',
#   '105',
#   '121',
#   '055',
#   '030',
#   '046',
#   '031',
#   '029',
#   '026',
#   '126',
#   '114'],
#  ['653', '002', '121', '009', '002', '008'],
#  ['003', '009', '002'],
#  ['612',
#   '045',
#   '057',
#   '018',
#   '856',
#   '025',
#   '023',
#   '002',
#   '009',
#   '832',
#   '021',
#   '016',
#   '098',
#   '109',
#   '031',
#   '118',
#   '123',
#   '128'],
#  ['003', '005', '010', '014', '001'],
#  ['403', '055', '403', '011'],
#  ['586',
#   '002',
#   '009',
#   '008',
#   '013',
#   '026',
#   '024',
#   '022',
#   '020',
#   '018',
#   '016',
#   '025',
#   '023',
#   '021',
#   '019',
#   '017',
#   '029',
#   '027',
#   '046',
#   '030',
#   '031',
#   '30'],
#  ['002', '009', '611', '028'],
#  ['403', '001', '005'],
#  ['027', '003', '006'],
#  ['005', '004', '012', '001'],
#  ['005', '402', '009'],
#  ['002', '016', '003'],
#  ['402', '023', '022'],
#  ['009', '006', '010'],
#  ['126', '131', '008', '132', '132', '413'],
#  ['002', '016', '072', '065', '022'],
#  ['009',
#   '606',
#   '040',
#   '403',
#   '005',
#   '001',
#   '016',
#   '002',
#   '008',
#   '017',
#   '020',
#   '018',
#   '024',
#   '022',
#   '021',
#   '019',
#   '026',
#   '610',
#   '031',
#   '009'],
#  ['070', '403', '001', '004', '005', '010'],
#  ['077', '072', '068', '065'],
#  ['005', '002', '641'],
#  ['002', '036', '001', '009', '003', '005'],
#  ['002', '403', '005'],
#  ['003', '005', '003', '014'],
#  ['827', '026', '610', '002'],
#  ['005', '005', '005', '004'],
#  ['009', '002', '610', '003', '005', '008'],
#  ['005', '003', '001'],
#  ['056', '610', '036', '002', '008', '057'],
#  ['005', '055', '009'],
#  ['003', '008', '019', '069'],
#  ['005', '004', '001', '001'],
#  ['055', '403'],
#  ['036',
#   '002',
#   '035',
#   '086',
#   '022',
#   '887',
#   '032',
#   '046',
#   '051',
#   '066',
#   '072',
#   '069',
#   '018',
#   '005',
#   '102',
#   '104',
#   '105',
#   '106',
#   '864',
#   '045',
#   '115',
#   '009',
#   '058',
#   '060',
#   '065',
#   '122',
#   '003',
#   '124',
#   '126',
#   '125',
#   '085',
#   '090',
#   '129',
#   '096',
#   '883',
#   '834'],
#  ['003',
#   '003',
#   '055',
#   '008',
#   '002',
#   '086',
#   '019',
#   '016',
#   '069',
#   '017',
#   '046',
#   '002',
#   '001',
#   '097',
#   '011',
#   '098',
#   '101'],
#  ['036', '002', '046', '009', '022', '22', '031', '025', '029', '033'],
#  ['031', '026', '008', '021', '086'],
#  ['003', '007', '009', '002'],
#  ['006', '511', '003', '002'],
#  ['022', '016', '033', '061', '869', '028', '065', '831'],
#  ['402', '006', '007'],
#  ['124', '122', '544', '127', '819'],
#  ['011', '015', '800', '615', '069'],
#  ['002', '081', '005', '077'],
#  ['003',
#   '402',
#   '002',
#   '008',
#   '036',
#   '017',
#   '009',
#   '005',
#   '041',
#   '030',
#   '002',
#   '025',
#   '019',
#   '024',
#   '069',
#   '070',
#   '029',
#   '020',
#   '080',
#   '077',
#   '021'],
#  ['002', '059', '856', '040'],
#  ['014', '003', '005', '008'],
#  ['001', '002', '009'],
#  ['606', '077', '017', '832', '021'],
#  ['005', '003', '004'],
#  ['003', '3', '015', '012'],
#  ['009', '005', '021'],
#  ['059', '003', '005', '027'],
#  ['805',
#   '010',
#   '059',
#   '062',
#   '030',
#   '024',
#   '028',
#   '069',
#   '023',
#   '862',
#   '020',
#   '025',
#   '863',
#   '085',
#   '861',
#   '885',
#   '884'],
#  ['402', '009', '055', '005'],
#  ['015', '016', '073', '027', '072'],
#  ['005', '002', '009', '090', '084', '073', '079', '006'],
#  ['013', '016', '055', '021', '027', '002', '033', '017', '653', '872'],
#  ['655', '004', '007'],
#  ['134', '008', '009'],
#  ['002',
#   '008',
#   '531',
#   '109',
#   '104',
#   '102',
#   '100',
#   '006',
#   '009',
#   '108',
#   '106',
#   '103',
#   '111',
#   '097',
#   '099',
#   '096',
#   '092',
#   '090',
#   '084',
#   '079',
#   '101',
#   '113'],
#  ['023', '021', '020', '018', '009', '611', '002', '403', '002', '009'],
#  ['002', '055'],
#  ['005', '002', '024', '022', '021', '019', '017'],
#  ['003', '001', '3', '1'],
#  ['402', '002', '040'],
#  ['002', '003', '653', '069'],
#  ['002', '024', '025', '017', '016', '067', '831'],
#  ['403', '035', '005', '834', '055'],
#  ['002', '009', '023', '017', '024', '046', '020'],
#  ['403', '126', '124'],
#  ['403', '001', '002'],
#  ['003', '001', '1', '012', '004'],
#  ['003', '005', '124'],
#  ['035', '031', '055'],
#  ['007', '004', '008', '046', '008', '024', '009', '026', '070'],
#  ['005', '003', '005', '005'],
#  ['039'],
#  ['002', '102', '018', '068', '024'],
#  ['622', '002', '055'],
#  ['016',
#   '020',
#   '021',
#   '003',
#   '027',
#   '051',
#   '005',
#   '002',
#   '084',
#   '065',
#   '055',
#   '003',
#   '096',
#   '864',
#   '108',
#   '002'],
#  ['002', '020', '069'],
#  ['005', '003', '885', '606'],
#  ['128', '129', '628', '625'],
#  ['005', '006', '832', '023', '869'],
#  ['011', '008', '026', '009', '002'],
#  ['007', '563', '403'],
#  ['110', '008', '002', '009'],
#  ['002', '403', '017', '019'],
#  ['005',
#   '002',
#   '020',
#   '018',
#   '025',
#   '095',
#   '002',
#   '009',
#   '103',
#   '082',
#   '027',
#   '117'],
#  ['002', '611', '011'],
#  ['009',
#   '005',
#   '016',
#   '017',
#   '018',
#   '016',
#   '002',
#   '622',
#   '020',
#   '017',
#   '027',
#   '009',
#   '060'],
#  ['403', '005', '062', '862', '018', '610', '076', '055'],
#  ['003', '026', '031', '008', '005', '074'],
#  ['035', '403', '036', '002', '001', '005'],
#  ['011',
#   '002',
#   '017',
#   '009',
#   '028',
#   '051',
#   '012',
#   '007',
#   '032',
#   '081',
#   '001',
#   '005',
#   '004'],
#  ['006',
#   '005',
#   '090',
#   '084',
#   '029',
#   '092',
#   '824',
#   '868',
#   '095',
#   '872',
#   '046',
#   '026',
#   '022',
#   '065',
#   '102',
#   '030',
#   '516',
#   '103',
#   '069',
#   '002',
#   '105',
#   '106',
#   '055',
#   '027',
#   '025',
#   '107',
#   '033',
#   '108',
#   '085',
#   '109',
#   '087',
#   '111',
#   '112',
#   '032',
#   '004',
#   '001',
#   '113',
#   '094',
#   '079',
#   '118',
#   '121',
#   '126'],
#  ['403', '055', '653'],
#  ['026',
#   '005',
#   '002',
#   '055',
#   '610',
#   '610',
#   '832',
#   '030',
#   '046',
#   '046',
#   '009',
#   '008',
#   '018',
#   '011'],
#  ['011', '402', '017', '027'],
#  ['055', '653'],
#  ['126', '589', '002', '009'],
#  ['001',
#   '001',
#   '004',
#   '004',
#   '012',
#   '012',
#   '005',
#   '063',
#   '006',
#   '064',
#   '002',
#   '025',
#   '111'],
#  ['035', '011', '041', '023'],
#  ['610', '009', '002', '013', '005', '015', '008', '403'],
#  ['005', '403', '014', '5', '403', '14'],
#  ['079',
#   '100',
#   '009',
#   '103',
#   '021',
#   '003',
#   '005',
#   '031',
#   '089',
#   '030',
#   '002',
#   '119',
#   '117',
#   '610',
#   '073',
#   '084',
#   '126',
#   '128',
#   '126',
#   '127',
#   '033'],
#  ['003', '002', '003'],
#  ['009',
#   '008',
#   '618',
#   '005',
#   '055',
#   '002',
#   '094',
#   '098',
#   '101',
#   '046',
#   '107',
#   '110',
#   '108',
#   '033',
#   '027',
#   '073',
#   '113',
#   '114',
#   '031',
#   '117',
#   '857',
#   '119',
#   '120',
#   '024',
#   '022',
#   '020',
#   '019',
#   '017',
#   '026',
#   '072',
#   '122',
#   '025',
#   '068',
#   '058',
#   '056',
#   '124',
#   '884',
#   '887',
#   '126',
#   '060',
#   '051',
#   '032',
#   '065',
#   '131',
#   '872'],
#  ['085', '084', '002', '106', '107', '113', '079', '115', '029'],
#  ['002', '005', '587'],
#  ['005', '035', '003', '3', '014', '014'],
#  ['098', '009', '009', '109', '109'],
#  ['402', '008', '403', '002', '015', '020', '019', '016', '019', '005'],
#  ['002', '009', '587'],
#  ['003', '005', '002'],
#  ['009', '402', '008'],
#  ['009', '622', '622'],
#  ['402',
#   '009',
#   '017',
#   '016',
#   '091',
#   '005',
#   '068',
#   '106',
#   '046',
#   '024',
#   '022',
#   '061',
#   '072',
#   '069',
#   '031',
#   '029',
#   '028',
#   '130',
#   '027',
#   '025',
#   '126',
#   '051',
#   '065',
#   '030',
#   '046',
#   '031',
#   '827',
#   '030',
#   '819'],
#  ['009', '002', '002', '022', '047', '060', '611'],
#  ['008', '006', '006', '006', '054', '031', '581', '030'],
#  ['119', '402', '009'],
#  ['002', '869', '024'],
#  ['002', '009', '036', '016', '622', '832'],
#  ['005', '403', '624', '009', '002', '031', '030', '046', '024', '023', '032'],
#  ['009', '611', '002', '403', '090', '005', '109', '128'],
#  ['403', '014', '005', '010'],
#  ['025', '025', '25', '25'],
#  ['001', '014', '005', '010', '070'],
#  ['403', '005', '010'],
#  ['077',
#   '008',
#   '002',
#   '005',
#   '005',
#   '832',
#   '046',
#   '801',
#   '857',
#   '023',
#   '610',
#   '019',
#   '024',
#   '088',
#   '884',
#   '089',
#   '610',
#   '016',
#   '069',
#   '005',
#   '090',
#   '881',
#   '881',
#   '869',
#   '093',
#   '868',
#   '872',
#   '095',
#   '822',
#   '103',
#   '102',
#   '403',
#   '004',
#   '115',
#   '112',
#   '114',
#   '121',
#   '126',
#   '124',
#   '127',
#   '834',
#   '818'],
#  ['606', '614', '002', '009', '008'],
#  ['006', '002', '533'],
#  ['005', '622', '009', '002'],
#  ['009', '002', '611', '9', '2', '611'],
#  ['055', '083', '055'],
#  ['082', '586', '002', '055'],
#  ['012', '001', '013', '008', '403', '004'],
#  ['041',
#   '046',
#   '049',
#   '047',
#   '059',
#   '061',
#   '040',
#   '023',
#   '865',
#   '852',
#   '080',
#   '864',
#   '081',
#   '046',
#   '011',
#   '869'],
#  ['009',
#   '003',
#   '005',
#   '036',
#   '014',
#   '016',
#   '017',
#   '018',
#   '035',
#   '041',
#   '002',
#   '024'],
#  ['403', '014', '023', '610', '002'],
#  ['002', '009', '003'],
#  ['003', '005', '007', '069'],
#  ['005', '007', '541'],
#  ['059',
#   '057',
#   '045',
#   '052',
#   '051',
#   '032',
#   '055',
#   '009',
#   '003',
#   '072',
#   '068',
#   '005',
#   '023',
#   '049',
#   '080',
#   '073',
#   '086',
#   '084',
#   '069',
#   '066'],
#  ['002', '015', '008', '012'],
#  ['403', '005', '018'],
#  ['023', '031', '051', '050', '026', '056'],
#  ['055', '005', '002', '004', '021', '009', '024'],
#  ['098', '055', '018', '003'],
#  ['017', '025', '027', '016', '022', '072', '053', '073', '069', '026', '056'],
#  ['017', '018', '005', '016', '008', '031', '100', '105', '879'],
#  ['403', '005', '004', '002', '005'],
#  ['122', '512', '005', '015', '507'],
#  ['002', '009', '015', '062', '056', '856', '073'],
#  ['001', '005', '004'],
#  ['005', '002', '009'],
#  ['001', '648', '652', '027', '026'],
#  ['123', '121', '002', '887', '119', '002', '047'],
#  ['005', '006', '002', '002'],
#  ['002', '009', '015', '008'],
#  ['011',
#   '002',
#   '008',
#   '055',
#   '015',
#   '004',
#   '001',
#   '613',
#   '102',
#   '002',
#   '008',
#   '008',
#   '403'],
#  ['005', '002', '511'],
#  ['102', '011', '009', '002', '653', '098'],
#  ['402', '002', '501'],
#  ['057', '053', '015', '075', '020', '079', '052'],
#  ['005',
#   '006',
#   '007',
#   '002',
#   '008',
#   '029',
#   '026',
#   '031',
#   '003',
#   '511',
#   '053',
#   '009',
#   '024',
#   '025',
#   '089',
#   '045',
#   '006',
#   '057',
#   '008',
#   '019',
#   '026'],
#  ['011', '856', '863', '085'],
#  ['003', '014', '010', '001'],
#  ['003', '035'],
#  ['055', '003'],
#  ['006', '002', '011', '009'],
#  ['003', '005', '002'],
#  ['003', '800', '007', '004', '002'],
#  ['022', '041', '023', '002'],
#  ['002', '009', '008'],
#  ['586', '009', '015'],
#  ['610',
#   '402',
#   '402',
#   '036',
#   '002',
#   '009',
#   '035',
#   '402',
#   '011',
#   '040',
#   '016',
#   '017',
#   '023',
#   '059'],
#  ['002',
#   '090',
#   '005',
#   '016',
#   '009',
#   '606',
#   '016',
#   '016',
#   '092',
#   '095',
#   '020',
#   '019',
#   '018',
#   '065',
#   '060',
#   '068',
#   '066',
#   '058',
#   '056',
#   '053',
#   '052',
#   '029',
#   '027',
#   '025',
#   '002',
#   '096',
#   '009',
#   '008',
#   '031',
#   '030',
#   '093',
#   '094'],
#  ['017',
#   '016',
#   '026',
#   '002',
#   '029',
#   '024',
#   '072',
#   '005',
#   '085',
#   '082',
#   '108',
#   '090',
#   '115',
#   '857'],
#  ['009', '002', '055', '623', '403', '082', '864', '109', '107'],
#  ['002', '005', '018'],
#  ['005', '403', '002', '002', '009', '029', '534'],
#  ['097', '617', '016', '002'],
#  ['005', '403', '002'],
#  ['403', '026', '002', '008', '096'],
#  ['132', '131', '647', '002'],
#  ['002', '118', '003', '001', '001', '001'],
#  ['012', '001', '010', '014', '005', '008'],
#  ['006', '531', '013', '041', '008', '026', '046', '025'],
#  ['009', '586', '004'],
#  ['001', '018', '016'],
#  ['003', '403', '403', '413', '413', '403', '003', '403', '413', '003', '002'],
#  ['055', '005', '009', '008', '002', '615', '016', '118'],
#  ['012', '001', '035', '039', '070'],
#  ['003', '002', '006', '008'],
#  ['005', '114', '113', '103'],
#  ['002', '036', '046', '030', '052', '46', '30', '858', '015', '005', '079'],
#  ['872', '002', '622', '403', '047', '005', '095', '017'],
#  ['002',
#   '009',
#   '008',
#   '098',
#   '016',
#   '017',
#   '101',
#   '100',
#   '055',
#   '021',
#   '019',
#   '027',
#   '026',
#   '024',
#   '023',
#   '864',
#   '079',
#   '107',
#   '106',
#   '072',
#   '068',
#   '066',
#   '058',
#   '108',
#   '060',
#   '069',
#   '403',
#   '005',
#   '109',
#   '104',
#   '065',
#   '121',
#   '119',
#   '117',
#   '831',
#   '887',
#   '084',
#   '073',
#   '606',
#   '031',
#   '029',
#   '028'],
#  ['005', '403', '014', '004'],
#  ['002', '009', '622', '095'],
#  ['015', '008', '005', '099'],
#  ['010', '003', '007', '002', '021', '018', '073'],
#  ['005', '085', '079', '072', '606', '077'],
#  ['003', '005', '004', '070', '005', '014', '001'],
#  ['009', '041', '024'],
#  ['003', '055', '009', '074', '863'],
#  ['002', '009', '008', '625'],
#  ['003', '005', '054', '055'],
#  ['017',
#   '802',
#   '020',
#   '055',
#   '820',
#   '018',
#   '856',
#   '074',
#   '080',
#   '861',
#   '087',
#   '086',
#   '885']]
